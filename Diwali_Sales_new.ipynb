# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### import python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### import csv file

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Assignments/Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ### drop unrelated/blank columns

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### check for null values

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# ## drop null values

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# ## change data type

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df.Amount.dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ## rename columns and values

# %%
df.rename(columns={'Cust_name':'Customer_name'},inplace=True)

# %%
df['Marital_Status'].replace({1: 'Unmarried', 0: 'Married'},inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ## description of the data

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['User_ID','Age','Amount']].describe()
# Out:
#             User_ID           Age        Amount
# count  1.123900e+04  11239.000000  11239.000000
# mean   1.003004e+06     35.410357   9453.610553
# std    1.716039e+03     12.753866   5222.355168
# min    1.000001e+06     12.000000    188.000000
# 25%    1.001492e+06     27.000000   5443.000000
# 50%    1.003064e+06     33.000000   8109.000000
# 75%    1.004426e+06     43.000000  12675.000000
# max    1.006040e+06     92.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ##Gender

# %% [markdown]
# ### plotting a bar chart for Gender and it's count

# %%
ax=sns.countplot(x='Gender',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '7832'), Text(0, 0, '3407')]

# %% [markdown]
# ### plotting a bar chart for gender vs total amount

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False)
sx=sns.barplot(x='Gender',y='Amount',data=sales_gen)
sx.bar_label(sx.containers[0])
# Out:
# [Text(0, 0, '7.43359e+07'), Text(0, 0, '3.19133e+07')]

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ##Age

# %%
dx=df['Age Group'].sort_values().unique()
ax=sns.countplot(x='Age Group',data=df,order=dx,hue='Gender')
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# ###Total Amount vs Age Group

# %%
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
dx=sns.barplot(x='Age Group',y='Amount',data=sales_age)
for bars in dx.containers:
  dx.bar_label(bars, fmt='%.0f')

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# ##State

# %% [markdown]
# ### total number of orders from top 10 states

# %%
sales_state=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.set(rc={'figure.figsize':(18,5)})
dx=sns.barplot(x='State',y='Orders',data=sales_state)
for bars in dx.containers:
  dx.bar_label(bars)

# %% [markdown]
# ### total amount/sales from top 10 states

# %%
sales_state=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(18,5)})
dx=sns.barplot(x='State',y='Amount',data=sales_state)
for bars in dx.containers:
  dx.bar_label(bars)

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ##Marital Status

# %%
ax=sns.countplot(x='Marital_Status',data=df)
sns.set(rc={'figure.figsize':(3,3)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_marr=df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
dx=sns.barplot(x='Marital_Status',y='Amount',data=sales_marr,hue='Gender')

# %% [markdown]
# From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# ## Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
dx = sns.countplot(x='Occupation', data=df)
for bars in dx.containers:
  dx.bar_label(bars)

# %%
sales_work=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.barplot(x='Occupation',y='Amount',data=sales_work)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# ## Product Category

# %%
sns.set(rc={'figure.figsize':(25,5)})
dx = sns.countplot(x='Product_Category', data=df)
for bars in dx.containers:
  dx.bar_label(bars)

# %%
sales_prod=df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.barplot(x='Product_Category',y='Amount',data=sales_prod)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category

# %%
sales_id=df.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.barplot(x='Product_ID',y='Orders',data=sales_id)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
